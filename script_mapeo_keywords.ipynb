# %% [markdown]
# <a href="https://colab.research.google.com/github/rgbb/proyecto001/blob/testing_rg/script_mapeo_keywords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# script_mapeo_keywords_colab_local.py

# Autor: Machine Learning & AI Solutions Team
# Descripción: Comparación de modelos multilingües para mapeo semántico de keywords con procesamiento incremental (versión local Colab)

# ================================
# 1. Instalación de dependencias
# ================================
# !pip install transformers sentence-transformers tqdm --quiet
# !pip install accelerate bitsandbytes --quiet  # Para modelos grandes como BGE o Granite

# ================================
# 2. Importaciones
# ================================
import os
import pandas as pd
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModel
from torch.nn.functional import cosine_similarity, normalize
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

# ================================
# 3. Montar Google Drive
# ================================
from google.colab import drive
drive.mount('/content/drive')

# Definir carpeta persistente en Google Drive (nombre de la carpeta a crear previamente: "keywords")
carpeta_drive = '/content/drive/MyDrive/keywords'

# Asegurar que la carpeta existe
os.makedirs(carpeta_drive, exist_ok=True)

# Rutas de archivos en Google Drive
archivo_entrada = os.path.join(carpeta_drive, 'keywords.csv')
archivo_resultado = os.path.join(carpeta_drive, 'resultados_comparacion_final.csv')
archivo_resumen = os.path.join(carpeta_drive, 'resumen_modelos_final.csv')

# ================================
# 4. Cargar datos fuente
# ================================
df = pd.read_csv(archivo_entrada)
df = df[df['keyword_get'].notna() & df['keyword_let'].notna()].reset_index(drop=True)
df['keyword_get'] = df['keyword_get'].astype(str)
df['keyword_let'] = df['keyword_let'].astype(str)
unique_keyword_let = df['keyword_let'].drop_duplicates().tolist()

# ================================
# 5. Cargar modelos
# ================================
model_infos = {
    'st_miniLM': SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2'),
    'bge_m3': ('BAAI/bge-m3', None),
    'gte': ('Alibaba-NLP/gte-multilingual-base', None),
    'e5': ('intfloat/multilingual-e5-base', None),
    'granite': ('ibm-granite/granite-embedding-278m-multilingual', None),
}

def load_transformer_model(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
    model = AutoModel.from_pretrained(model_name, trust_remote_code=True)
    return tokenizer, model

# ================================
# 6. Calcular embeddings de referencia
# ================================
reference_embeddings = {}
reference_embeddings['st_miniLM'] = torch.tensor(
    model_infos['st_miniLM'].encode(unique_keyword_let, convert_to_numpy=True)
)

for key in ['bge_m3', 'gte', 'e5', 'granite']:
    tokenizer, model = load_transformer_model(model_infos[key][0])
    model_infos[key] = (tokenizer, model)
    embs = []
    for text in tqdm(unique_keyword_let, desc=f'Embeddings {key}'):
        encoded = tokenizer(text, return_tensors='pt', truncation=True, padding=True)
        with torch.no_grad():
            output = model(**encoded)
        cls_embedding = output.last_hidden_state[:, 0]
        normalized = normalize(cls_embedding, p=2, dim=1)
        embs.append(normalized)
    reference_embeddings[key] = torch.cat(embs, dim=0)

# ================================
# 7. Reanudar si hay resultados previos
# ================================
if os.path.exists(archivo_resultado):
    df_resultado = pd.read_csv(archivo_resultado)
    procesados = df_resultado['keyword_get'].tolist()
    print(f"🟡 Retomando desde registro {len(procesados)}...")
else:
    df_resultado = pd.DataFrame()
    procesados = []

df_pendientes = df[~df['keyword_get'].isin(procesados)].reset_index(drop=True)

# ================================
# 8. Función de comparación
# ================================
def comparar_modelos_full(text):
    resultados = {}
    emb_st = torch.tensor(model_infos['st_miniLM'].encode([text])[0])
    sims_st = cosine_similarity(emb_st.unsqueeze(0), reference_embeddings['st_miniLM']).squeeze(0)
    idx_st = torch.argmax(sims_st).item()
    resultados['match_st_miniLM'] = unique_keyword_let[idx_st]
    resultados['sim_st_miniLM'] = sims_st[idx_st].item() * 100

    for key in ['bge_m3', 'gte', 'e5', 'granite']:
        tokenizer, model = model_infos[key]
        encoded = tokenizer(text, return_tensors='pt', truncation=True, padding=True)
        with torch.no_grad():
            output = model(**encoded)
        emb = normalize(output.last_hidden_state[:, 0], p=2, dim=1)
        sims = cosine_similarity(emb, reference_embeddings[key]).squeeze(0)
        idx = torch.argmax(sims).item()
        resultados[f'match_{key}'] = unique_keyword_let[idx]
        resultados[f'sim_{key}'] = sims[idx].item() * 100

    return pd.Series(resultados)

# ================================
# 9. Procesamiento por lotes
# ================================
batch_size = 100
total = len(df_pendientes)

for i, row in df_pendientes.iterrows():
    text = row['keyword_get']
    result = comparar_modelos_full(text)
    fila_resultado = pd.Series({
        'keyword_get': row['keyword_get'],
        'keyword_let': row['keyword_let'],
        **result.to_dict()
    })

    df_resultado = pd.concat([df_resultado, fila_resultado.to_frame().T], ignore_index=True)

    # Guardar después de cada batch para evitar pérdida en caso de reinicio
    if (i + 1) % batch_size == 0 or (i + 1) == total:
        df_resultado.to_csv(archivo_resultado, index=False)
        print(f"✅ Guardado: {i+1} procesados de {total} | Pendientes: {total - (i+1)}")

# ================================
# 10. Generar resumen
# ================================
resumen = {}
for col in [c for c in df_resultado.columns if c.startswith('match_')]:
    aciertos = (df_resultado[col] == df_resultado['keyword_let']).sum()
    resumen[col] = {
        'Coincidencias': aciertos,
        'Porcentaje de aciertos (%)': round(aciertos / len(df_resultado) * 100, 2),
    }

pd.DataFrame.from_dict(resumen, orient='index').to_csv(archivo_resumen)
print('🎉 Proceso finalizado y resumen guardado.')
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# Embeddings bge_m3:   0%|          | 0/4195 [00:00<?, ?it/s]
# Embeddings bge_m3:   0%|          | 1/4195 [00:00<1:04:32,  1.08it/s]
# Embeddings bge_m3:   0%|          | 2/4195 [00:01<49:45,  1.40it/s]
# Embeddings bge_m3:   0%|          | 3/4195 [00:01<39:39,  1.76it/s]
# Embeddings bge_m3:   0%|          | 4/4195 [00:02<31:30,  2.22it/s]
# Embeddings bge_m3:   0%|          | 5/4195 [00:02<26:46,  2.61it/s]
# Embeddings bge_m3:   0%|          | 6/4195 [00:02<24:22,  2.86it/s]
# Embeddings bge_m3:   0%|          | 7/4195 [00:03<26:30,  2.63it/s]
# Embeddings bge_m3:   0%|          | 8/4195 [00:03<32:57,  2.12it/s]
# Embeddings bge_m3:   0%|          | 9/4195 [00:04<36:28,  1.91it/s]
# Embeddings bge_m3:   0%|          | 10/4195 [00:05<37:06,  1.88it/s]
# Embeddings bge_m3:   0%|          | 11/4195 [00:05<38:47,  1.80it/s]
# Embeddings bge_m3:   0%|          | 12/4195 [00:06<39:31,  1.76it/s]
# Embeddings bge_m3:   0%|          | 13/4195 [00:06<37:13,  1.87it/s]
# Embeddings bge_m3:   0%|          | 14/4195 [00:06<32:09,  2.17it/s]
# Embeddings bge_m3:   0%|          | 15/4195 [00:07<29:21,  2.37it/s]
# Embeddings bge_m3:   0%|          | 16/4195 [00:07<27:49,  2.50it/s]
# Embeddings bge_m3:   0%|          | 17/4195 [00:07<26:13,  2.66it/s]
# Embeddings bge_m3:   0%|          | 18/4195 [00:08<25:12,  2.76it/s]
# Embeddings bge_m3:   0%|          | 19/4195 [00:08<24:52,  2.80it/s]
# Embeddings bge_m3:   0%|          | 20/4195 [00:09<27:11,  2.56it/s]
# Embeddings bge_m3:   1%|          | 21/4195 [00:09<25:38,  2.71it/s]
# Embeddings bge_m3:   1%|          | 22/4195 [00:09<25:50,  2.69it/s]
# Embeddings bge_m3:   1%|          | 23/4195 [00:10<33:10,  2.10it/s]
# Embeddings bge_m3:   1%|          | 24/4195 [00:11<35:03,  1.98it/s]
# Embeddings bge_m3:   1%|          | 25/4195 [00:11<33:03,  2.10it/s]
# Embeddings bge_m3:   1%|          | 26/4195 [00:11<30:21,  2.29it/s]
# Embeddings bge_m3:   1%|          | 27/4195 [00:12<27:10,  2.56it/s]
# Embeddings bge_m3:   1%|          | 28/4195 [00:12<26:21,  2.64it/s]
# Embeddings bge_m3:   1%|          | 29/4195 [00:12<25:11,  2.76it/s]
# Embeddings bge_m3:   1%|          | 30/4195 [00:13<23:51,  2.91it/s]
# Embeddings bge_m3:   1%|          | 31/4195 [00:13<22:14,  3.12it/s]
# Embeddings bge_m3:   1%|          | 32/4195 [00:13<22:38,  3.07it/s]
# Embeddings bge_m3:   1%|          | 33/4195 [00:14<28:49,  2.41it/s]
# Embeddings bge_m3:   1%|          | 34/4195 [00:14<31:55,  2.17it/s]
# Embeddings bge_m3:   1%|          | 35/4195 [00:15<27:56,  2.48it/s]
# Embeddings bge_m3:   1%|          | 36/4195 [00:15<25:20,  2.74it/s]
# Embeddings bge_m3:   1%|          | 37/4195 [00:15<23:21,  2.97it/s]
# Embeddings bge_m3:   1%|          | 38/4195 [00:16<22:21,  3.10it/s]
# Embeddings bge_m3:   1%|          | 39/4195 [00:16<21:37,  3.20it/s]
# Embeddings bge_m3:   1%|          | 40/4195 [00:16<20:49,  3.33it/s]
# Embeddings bge_m3:   1%|          | 41/4195 [00:16<20:11,  3.43it/s]
# Embeddings bge_m3:   1%|          | 42/4195 [00:17<19:41,  3.51it/s]
# Embeddings bge_m3:   1%|          | 43/4195 [00:17<21:42,  3.19it/s]
# Embeddings bge_m3:   1%|          | 44/4195 [00:18<27:36,  2.51it/s]
# Embeddings bge_m3:   1%|          | 45/4195 [00:18<29:41,  2.33it/s]
# Embeddings bge_m3:   1%|          | 46/4195 [00:18<26:28,  2.61it/s]
# Embeddings bge_m3:   1%|          | 47/4195 [00:19<23:58,  2.88it/s]
# Embeddings bge_m3:   1%|          | 48/4195 [00:20<38:49,  1.78it/s]
# Embeddings bge_m3:   1%|          | 49/4195 [00:20<42:37,  1.62it/s]
# Embeddings bge_m3:   1%|          | 50/4195 [00:21<39:25,  1.75it/s]
# Embeddings bge_m3:   1%|          | 51/4195 [00:22<45:12,  1.53it/s]
# Embeddings bge_m3:   1%|          | 52/4195 [00:22<42:31,  1.62it/s]
# Embeddings bge_m3:   1%|▏         | 53/4195 [00:23<36:38,  1.88it/s]
# Embeddings bge_m3:   1%|▏         | 54/4195 [00:25<1:21:40,  1.18s/it]
# Embeddings bge_m3:   1%|▏         | 55/4195 [00:26<1:09:55,  1.01s/it]
# Embeddings bge_m3:   1%|▏         | 56/4195 [00:26<1:00:10,  1.15it/s]
# Embeddings bge_m3:   1%|▏         | 57/4195 [00:29<1:34:47,  1.37s/it]
# Embeddings bge_m3:   1%|▏         | 58/4195 [00:30<1:16:33,  1.11s/it]
# Embeddings bge_m3:   1%|▏         | 59/4195 [00:30<58:44,  1.17it/s]
# Embeddings bge_m3:   1%|▏         | 60/4195 [00:30<46:26,  1.48it/s]
# Embeddings bge_m3:   1%|▏         | 61/4195 [00:30<37:32,  1.84it/s]
# Embeddings bge_m3:   1%|▏         | 62/4195 [00:31<31:37,  2.18it/s]
# Embeddings bge_m3:   2%|▏         | 63/4195 [00:31<27:29,  2.50it/s]
# Embeddings bge_m3:   2%|▏         | 64/4195 [00:31<24:27,  2.81it/s]
# Embeddings bge_m3:   2%|▏         | 65/4195 [00:31<22:39,  3.04it/s]
# Embeddings bge_m3:   2%|▏         | 66/4195 [00:32<21:15,  3.24it/s]
# Embeddings bge_m3:   2%|▏         | 67/4195 [00:32<20:55,  3.29it/s]
# Embeddings bge_m3:   2%|▏         | 68/4195 [00:32<19:48,  3.47it/s]
# Embeddings bge_m3:   2%|▏         | 69/4195 [00:32<19:23,  3.55it/s]
# Embeddings bge_m3:   2%|▏         | 70/4195 [00:33<18:53,  3.64it/s]
# Embeddings bge_m3:   2%|▏         | 71/4195 [00:33<18:18,  3.75it/s]
# Embeddings bge_m3:   2%|▏         | 72/4195 [00:33<17:37,  3.90it/s]
# Embeddings bge_m3:   2%|▏         | 73/4195 [00:33<17:13,  3.99it/s]
# Embeddings bge_m3:   2%|▏         | 74/4195 [00:34<16:50,  4.08it/s]
# Embeddings bge_m3:   2%|▏         | 75/4195 [00:34<17:06,  4.01it/s]
# Embeddings bge_m3:   2%|▏         | 76/4195 [00:34<17:00,  4.04it/s]
# Embeddings bge_m3:   2%|▏         | 77/4195 [00:34<16:57,  4.05it/s]
# Embeddings bge_m3:   2%|▏         | 78/4195 [00:35<16:40,  4.11it/s]
# Embeddings bge_m3:   2%|▏         | 79/4195 [00:35<17:08,  4.00it/s]
# Embeddings bge_m3:   4%|▎         | 149/4195 [00:55<16:49,  4.01it/s]
# Embeddings bge_m3:   4%|▎         | 150/4195 [00:55<16:27,  4.09it/s]
# Embeddings bge_m3:   4%|▎         | 151/4195 [00:56<16:23,  4.11it/s]
# Embeddings bge_m3:   4%|▎         | 152/4195 [00:56<16:48,  4.01it/s]
# Embeddings bge_m3:   4%|▎         | 153/4195 [00:56<16:49,  4.00it/s]
# Embeddings bge_m3:   4%|▎         | 154/4195 [00:56<16:35,  4.06it/s]
# Embeddings bge_m3:   4%|▎         | 155/4195 [00:57<17:19,  3.89it/s]
# Embeddings bge_m3:   4%|▎         | 156/4195 [00:57<17:07,  3.93it/s]
# Embeddings bge_m3:   4%|▎         | 157/4195 [00:57<16:47,  4.01it/s]
# Embeddings bge_m3:   4%|▍         | 158/4195 [00:57<16:28,  4.09it/s]
# Embeddings bge_m3:   4%|▍         | 159/4195 [00:58<16:23,  4.10it/s]
# Embeddings bge_m3:   4%|▍         | 160/4195 [00:58<16:40,  4.03it/s]
# Embeddings bge_m3:   4%|▍         | 161/4195 [00:58<17:02,  3.95it/s]
# Embeddings bge_m3:   4%|▍         | 162/4195 [00:58<16:49,  3.99it/s]
# Embeddings bge_m3:   4%|▍         | 163/4195 [00:59<16:38,  4.04it/s]
# Embeddings bge_m3:   4%|▍         | 164/4195 [00:59<16:41,  4.02it/s]
# Embeddings bge_m3:   4%|▍         | 165/4195 [00:59<16:31,  4.06it/s]
# Embeddings bge_m3:   4%|▍         | 166/4195 [00:59<16:37,  4.04it/s]
# Embeddings bge_m3:   4%|▍         | 167/4195 [01:00<16:32,  4.06it/s]
# Embeddings bge_m3:   4%|▍         | 168/4195 [01:00<16:34,  4.05it/s]
# Embeddings bge_m3:   4%|▍         | 169/4195 [01:00<16:42,  4.01it/s]
# Embeddings bge_m3:   4%|▍         | 170/4195 [01:00<16:30,  4.06it/s]
# Embeddings bge_m3:   4%|▍         | 171/4195 [01:01<16:44,  4.00it/s]
# Embeddings bge_m3:   4%|▍         | 172/4195 [01:01<16:41,  4.02it/s]
# Embeddings bge_m3:   4%|▍         | 173/4195 [01:01<16:36,  4.04it/s]
# Embeddings bge_m3:   4%|▍         | 174/4195 [01:01<16:23,  4.09it/s]
# Embeddings bge_m3:   4%|▍         | 175/4195 [01:02<16:24,  4.08it/s]
# Embeddings bge_m3:   4%|▍         | 176/4195 [01:02<17:05,  3.92it/s]
# Embeddings bge_m3:   4%|▍         | 177/4195 [01:02<16:47,  3.99it/s]
# Embeddings bge_m3:   4%|▍         | 178/4195 [01:02<17:11,  3.89it/s]
# Embeddings bge_m3:   4%|▍         | 179/4195 [01:03<17:09,  3.90it/s]
# Embeddings bge_m3:   4%|▍         | 180/4195 [01:03<17:07,  3.91it/s]
# Embeddings bge_m3:   4%|▍         | 181/4195 [01:03<17:20,  3.86it/s]
# Embeddings bge_m3:   4%|▍         | 182/4195 [01:04<18:56,  3.53it/s]
# Embeddings bge_m3:   4%|▍         | 183/4195 [01:04<19:59,  3.35it/s]
# Embeddings bge_m3:   9%|▉         | 391/4195 [02:01<20:45,  3.05it/s]
# Embeddings bge_m3:   9%|▉         | 392/4195 [02:02<21:07,  3.00it/s]
# Embeddings bge_m3:   9%|▉         | 393/4195 [02:02<21:21,  2.97it/s]
# Embeddings bge_m3:   9%|▉         | 394/4195 [02:02<22:00,  2.88it/s]
# Embeddings bge_m3:   9%|▉         | 395/4195 [02:03<22:18,  2.84it/s]
# Embeddings bge_m3:   9%|▉         | 396/4195 [02:03<22:19,  2.84it/s]
# Embeddings bge_m3:   9%|▉         | 397/4195 [02:04<22:24,  2.83it/s]
# Embeddings bge_m3:   9%|▉         | 398/4195 [02:04<22:34,  2.80it/s]
# Embeddings bge_m3:  10%|▉         | 399/4195 [02:04<21:59,  2.88it/s]
# Embeddings bge_m3:  10%|▉         | 400/4195 [02:04<20:11,  3.13it/s]
# Embeddings bge_m3:  10%|▉         | 401/4195 [02:05<19:01,  3.32it/s]
# Embeddings bge_m3:  10%|▉         | 402/4195 [02:05<18:16,  3.46it/s]
# Embeddings bge_m3:  10%|▉         | 403/4195 [02:05<17:45,  3.56it/s]
# Embeddings bge_m3:  10%|▉         | 404/4195 [02:05<17:08,  3.69it/s]
# Embeddings bge_m3:  10%|▉         | 405/4195 [02:06<17:07,  3.69it/s]
# Embeddings bge_m3:  10%|▉         | 406/4195 [02:06<16:23,  3.85it/s]
# Embeddings bge_m3:  10%|▉         | 407/4195 [02:06<16:00,  3.94it/s]
# Embeddings bge_m3:  10%|▉         | 408/4195 [02:06<16:03,  3.93it/s]
# Embeddings bge_m3:  10%|▉         | 409/4195 [02:07<15:59,  3.95it/s]
# Embeddings bge_m3:  10%|▉         | 410/4195 [02:07<16:05,  3.92it/s]
# Embeddings bge_m3:  10%|▉         | 411/4195 [02:07<15:56,  3.96it/s]
# Embeddings bge_m3:  10%|▉         | 412/4195 [02:07<15:47,  3.99it/s]
# Embeddings bge_m3:  10%|▉         | 413/4195 [02:08<15:59,  3.94it/s]
# Embeddings bge_m3:  10%|▉         | 414/4195 [02:08<16:10,  3.90it/s]
# Embeddings bge_m3:  10%|▉         | 415/4195 [02:08<16:20,  3.86it/s]
# Embeddings bge_m3:  10%|▉         | 416/4195 [02:09<16:13,  3.88it/s]
# Embeddings bge_m3:  10%|▉         | 417/4195 [02:09<16:00,  3.94it/s]
# Embeddings bge_m3:  10%|▉         | 418/4195 [02:09<16:05,  3.91it/s]
# Embeddings bge_m3:  10%|▉         | 419/4195 [02:09<16:04,  3.91it/s]
# Embeddings bge_m3:  10%|█         | 420/4195 [02:10<16:10,  3.89it/s]
# Embeddings bge_m3:  10%|█         | 421/4195 [02:10<16:23,  3.84it/s]
# Embeddings bge_m3:  10%|█         | 422/4195 [02:10<16:29,  3.81it/s]
# Embeddings bge_m3:  10%|█         | 423/4195 [02:10<16:16,  3.86it/s]
# Embeddings bge_m3:  10%|█         | 424/4195 [02:11<15:52,  3.96it/s]
# Embeddings bge_m3:  10%|█         | 425/4195 [02:11<23:47,  2.64it/s]
# Embeddings bge_m3:  13%|█▎        | 563/4195 [02:57<15:37,  3.87it/s]
# Embeddings bge_m3:  13%|█▎        | 564/4195 [02:58<15:50,  3.82it/s]
# Embeddings bge_m3:  13%|█▎        | 565/4195 [02:58<15:39,  3.86it/s]
# Embeddings bge_m3:  13%|█▎        | 566/4195 [02:58<16:36,  3.64it/s]
# Embeddings bge_m3:  14%|█▎        | 567/4195 [02:59<16:34,  3.65it/s]
# Embeddings bge_m3:  14%|█▎        | 568/4195 [02:59<16:01,  3.77it/s]
# Embeddings bge_m3:  14%|█▎        | 569/4195 [02:59<15:55,  3.80it/s]
# Embeddings bge_m3:  14%|█▎        | 570/4195 [02:59<16:37,  3.64it/s]
# Embeddings bge_m3:  14%|█▎        | 571/4195 [03:00<16:42,  3.62it/s]
# Embeddings bge_m3:  14%|█▎        | 572/4195 [03:00<16:33,  3.65it/s]
# Embeddings bge_m3:  14%|█▎        | 573/4195 [03:00<16:41,  3.62it/s]
# Embeddings bge_m3:  14%|█▎        | 574/4195 [03:01<16:48,  3.59it/s]
# Embeddings bge_m3:  14%|█▎        | 575/4195 [03:01<16:33,  3.65it/s]
# Embeddings bge_m3:  14%|█▎        | 576/4195 [03:01<16:09,  3.73it/s]
# Embeddings bge_m3:  14%|█▍        | 577/4195 [03:01<16:17,  3.70it/s]
# Embeddings bge_m3:  14%|█▍        | 578/4195 [03:02<16:11,  3.72it/s]
# Embeddings bge_m3:  14%|█▍        | 579/4195 [03:02<16:29,  3.65it/s]
# Embeddings bge_m3:  14%|█▍        | 580/4195 [03:02<16:22,  3.68it/s]
# Embeddings bge_m3:  14%|█▍        | 581/4195 [03:02<17:32,  3.43it/s]
# Embeddings bge_m3:  14%|█▍        | 582/4195 [03:03<19:11,  3.14it/s]
# Embeddings bge_m3:  14%|█▍        | 583/4195 [03:03<19:35,  3.07it/s]
# Embeddings bge_m3:  14%|█▍        | 584/4195 [03:03<19:34,  3.07it/s]
# Embeddings bge_m3:  14%|█▍        | 585/4195 [03:04<20:12,  2.98it/s]
# Embeddings bge_m3:  14%|█▍        | 586/4195 [03:04<20:46,  2.89it/s]
# Embeddings bge_m3:  14%|█▍        | 587/4195 [03:05<20:28,  2.94it/s]
# Embeddings bge_m3:  14%|█▍        | 588/4195 [03:05<20:39,  2.91it/s]
# Embeddings bge_m3:  14%|█▍        | 589/4195 [03:05<20:50,  2.88it/s]
# Embeddings bge_m3:  14%|█▍        | 590/4195 [03:06<21:53,  2.74it/s]
# Embeddings bge_m3:  14%|█▍        | 591/4195 [03:06<22:56,  2.62it/s]
# Embeddings bge_m3:  14%|█▍        | 592/4195 [03:06<23:03,  2.60it/s]
# Embeddings bge_m3:  14%|█▍        | 593/4195 [03:07<22:50,  2.63it/s]
# Embeddings bge_m3:  14%|█▍        | 594/4195 [03:07<21:43,  2.76it/s]
# Embeddings bge_m3:  14%|█▍        | 595/4195 [03:07<20:18,  2.95it/s]
# Embeddings bge_m3:  14%|█▍        | 596/4195 [03:08<19:37,  3.06it/s]
# Embeddings bge_m3:  14%|█▍        | 597/4195 [03:08<19:03,  3.15it/s]
# Embeddings bge_m3:  14%|█▍        | 598/4195 [03:08<19:01,  3.15it/s]
# Embeddings bge_m3:  14%|█▍        | 599/4195 [03:09<18:20,  3.27it/s]
# Embeddings bge_m3:  14%|█▍        | 600/4195 [03:09<17:50,  3.36it/s]
# Embeddings bge_m3:  14%|█▍        | 601/4195 [03:09<17:30,  3.42it/s]
# Embeddings bge_m3:  14%|█▍        | 602/4195 [03:09<17:03,  3.51it/s]
# Embeddings bge_m3:  14%|█▍        | 603/4195 [03:10<16:38,  3.60it/s]
# Embeddings bge_m3:  14%|█▍        | 604/4195 [03:10<16:14,  3.69it/s]
# Embeddings bge_m3:  14%|█▍        | 605/4195 [03:10<16:16,  3.67it/s]
# Embeddings bge_m3:  14%|█▍        | 606/4195 [03:11<16:22,  3.65it/s]
# Embeddings bge_m3:  14%|█▍        | 607/4195 [03:11<16:14,  3.68it/s]
# Embeddings bge_m3:  14%|█▍        | 608/4195 [03:11<15:45,  3.79it/s]
# Embeddings bge_m3:  15%|█▍        | 609/4195 [03:11<15:51,  3.77it/s]
# Embeddings bge_m3:  15%|█▍        | 610/4195 [03:12<16:01,  3.73it/s]
# Embeddings bge_m3:  15%|█▍        | 611/4195 [03:12<15:47,  3.78it/s]
# Embeddings bge_m3:  15%|█▍        | 612/4195 [03:12<15:41,  3.80it/s]
# Embeddings bge_m3:  15%|█▍        | 613/4195 [03:12<15:56,  3.75it/s]
# Embeddings bge_m3:  15%|█▍        | 614/4195 [03:13<15:42,  3.80it/s]
# Embeddings bge_m3:  15%|█▍        | 615/4195 [03:13<15:41,  3.80it/s]
# Embeddings bge_m3:  15%|█▍        | 616/4195 [03:13<16:06,  3.70it/s]
# Embeddings bge_m3:  15%|█▍        | 617/4195 [03:14<16:58,  3.51it/s]
# Embeddings bge_m3:  15%|█▍        | 618/4195 [03:14<16:51,  3.53it/s]
# Embeddings bge_m3:  15%|█▍        | 619/4195 [03:14<16:28,  3.62it/s]
# Embeddings bge_m3:  15%|█▍        | 620/4195 [03:14<17:15,  3.45it/s]
# Embeddings bge_m3:  15%|█▍        | 621/4195 [03:15<17:07,  3.48it/s]
# Embeddings bge_m3:  15%|█▍        | 622/4195 [03:15<16:33,  3.60it/s]
# Embeddings bge_m3:  15%|█▍        | 623/4195 [03:15<16:13,  3.67it/s]
# Embeddings bge_m3:  15%|█▍        | 624/4195 [03:15<16:18,  3.65it/s]
# Embeddings bge_m3:  15%|█▍        | 625/4195 [03:16<16:10,  3.68it/s]
# Embeddings bge_m3:  15%|█▍        | 626/4195 [03:16<16:08,  3.69it/s]
# Embeddings bge_m3:  15%|█▍        | 627/4195 [03:16<16:34,  3.59it/s]
# Embeddings bge_m3:  15%|█▍        | 628/4195 [03:17<17:04,  3.48it/s]
# Embeddings bge_m3:  15%|█▍        | 629/4195 [03:17<18:47,  3.16it/s]
# Embeddings bge_m3:  15%|█▌        | 630/4195 [03:17<19:43,  3.01it/s]
# Embeddings bge_m3:  15%|█▌        | 631/4195 [03:18<19:49,  3.00it/s]
# Embeddings bge_m3:  15%|█▌        | 632/4195 [03:18<20:35,  2.88it/s]
# Embeddings bge_m3:  15%|█▌        | 633/4195 [03:18<20:54,  2.84it/s]
# Embeddings bge_m3:  15%|█▌        | 634/4195 [03:19<21:27,  2.77it/s]
# Embeddings bge_m3:  15%|█▌        | 635/4195 [03:19<21:07,  2.81it/s]
# Embeddings bge_m3:  15%|█▌        | 636/4195 [03:20<22:03,  2.69it/s]
# Embeddings bge_m3:  15%|█▌        | 637/4195 [03:20<23:10,  2.56it/s]
# Embeddings bge_m3:  15%|█▌        | 638/4195 [03:20<23:35,  2.51it/s]
# Embeddings bge_m3:  15%|█▌        | 639/4195 [03:21<23:17,  2.55it/s]
# Embeddings bge_m3:  15%|█▌        | 640/4195 [03:21<22:25,  2.64it/s]
# Embeddings bge_m3:  15%|█▌        | 641/4195 [03:21<21:06,  2.81it/s]
# Embeddings bge_m3:  15%|█▌        | 642/4195 [03:22<19:19,  3.07it/s]
# Embeddings bge_m3:  15%|█▌        | 643/4195 [03:22<18:28,  3.21it/s]
# Embeddings bge_m3:  15%|█▌        | 644/4195 [03:22<17:33,  3.37it/s]
# Embeddings bge_m3:  15%|█▌        | 645/4195 [03:22<16:49,  3.52it/s]
# Embeddings bge_m3:  15%|█▌        | 646/4195 [03:23<16:10,  3.66it/s]
# Embeddings bge_m3:  15%|█▌        | 647/4195 [03:23<16:13,  3.65it/s]
# Embeddings bge_m3:  15%|█▌        | 648/4195 [03:23<15:52,  3.73it/s]
# Embeddings bge_m3:  15%|█▌        | 649/4195 [03:24<15:35,  3.79it/s]
# Embeddings bge_m3:  15%|█▌        | 650/4195 [03:24<15:39,  3.77it/s]
# Embeddings bge_m3:  16%|█▌        | 651/4195 [03:24<16:10,  3.65it/s]
# Embeddings bge_m3:  16%|█▌        | 652/4195 [03:24<15:47,  3.74it/s]
# Embeddings bge_m3:  16%|█▌        | 653/4195 [03:25<15:51,  3.72it/s]
# Embeddings bge_m3:  16%|█▌        | 654/4195 [03:25<16:00,  3.69it/s]
# Embeddings bge_m3:  16%|█▌        | 655/4195 [03:25<16:21,  3.61it/s]
# Embeddings bge_m3:  16%|█▌        | 656/4195 [03:25<15:54,  3.71it/s]
# Embeddings bge_m3:  16%|█▌        | 657/4195 [03:26<15:41,  3.76it/s]
# Embeddings bge_m3:  16%|█▌        | 658/4195 [03:26<15:57,  3.70it/s]
# Embeddings bge_m3:  16%|█▌        | 659/4195 [03:26<15:59,  3.68it/s]
# Embeddings bge_m3:  16%|█▌        | 660/4195 [03:27<15:55,  3.70it/s]
# Embeddings bge_m3:  16%|█▌        | 661/4195 [03:27<15:56,  3.70it/s]
# Embeddings bge_m3:  16%|█▌        | 662/4195 [03:27<16:00,  3.68it/s]
# Embeddings bge_m3:  16%|█▌        | 663/4195 [03:27<16:05,  3.66it/s]
# ...
# ✅ Guardado: 25500 procesados de 53033 | Pendientes: 27533
# ✅ Guardado: 25600 procesados de 53033 | Pendientes: 27433
# ✅ Guardado: 25700 procesados de 53033 | Pendientes: 27333
# ✅ Guardado: 25800 procesados de 53033 | Pendientes: 27233
# ✅ Guardado: 25900 procesados de 53033 | Pendientes: 27133
# ✅ Guardado: 26000 procesados de 53033 | Pendientes: 27033
# ✅ Guardado: 26100 procesados de 53033 | Pendientes: 26933
# ✅ Guardado: 26200 procesados de 53033 | Pendientes: 26833
# ✅ Guardado: 26300 procesados de 53033 | Pendientes: 26733
# ✅ Guardado: 26400 procesados de 53033 | Pendientes: 26633
# ✅ Guardado: 26500 procesados de 53033 | Pendientes: 26533
# ✅ Guardado: 26600 procesados de 53033 | Pendientes: 26433
# ✅ Guardado: 26700 procesados de 53033 | Pendientes: 26333
# ✅ Guardado: 26800 procesados de 53033 | Pendientes: 26233
# ✅ Guardado: 26900 procesados de 53033 | Pendientes: 26133
# ✅ Guardado: 27000 procesados de 53033 | Pendientes: 26033
# ✅ Guardado: 27100 procesados de 53033 | Pendientes: 25933
# ✅ Guardado: 27200 procesados de 53033 | Pendientes: 25833
# ✅ Guardado: 27300 procesados de 53033 | Pendientes: 25733
# ✅ Guardado: 27400 procesados de 53033 | Pendientes: 25633
# ✅ Guardado: 27500 procesados de 53033 | Pendientes: 25533
# ✅ Guardado: 27600 procesados de 53033 | Pendientes: 25433
# ✅ Guardado: 27700 procesados de 53033 | Pendientes: 25333
# ✅ Guardado: 27800 procesados de 53033 | Pendientes: 25233
# ✅ Guardado: 27900 procesados de 53033 | Pendientes: 25133
# ✅ Guardado: 28000 procesados de 53033 | Pendientes: 25033
# ✅ Guardado: 28100 procesados de 53033 | Pendientes: 24933
# ✅ Guardado: 28200 procesados de 53033 | Pendientes: 24833
# ✅ Guardado: 28300 procesados de 53033 | Pendientes: 24733
# ✅ Guardado: 28400 procesados de 53033 | Pendientes: 24633
# ✅ Guardado: 28500 procesados de 53033 | Pendientes: 24533
# ✅ Guardado: 28600 procesados de 53033 | Pendientes: 24433
# ✅ Guardado: 28700 procesados de 53033 | Pendientes: 24333
# ✅ Guardado: 28800 procesados de 53033 | Pendientes: 24233
# ✅ Guardado: 28900 procesados de 53033 | Pendientes: 24133
# ✅ Guardado: 29000 procesados de 53033 | Pendientes: 24033
# ✅ Guardado: 29100 procesados de 53033 | Pendientes: 23933
# ✅ Guardado: 29200 procesados de 53033 | Pendientes: 23833
# ✅ Guardado: 29300 procesados de 53033 | Pendientes: 23733
# ✅ Guardado: 29400 procesados de 53033 | Pendientes: 23633
# ✅ Guardado: 29500 procesados de 53033 | Pendientes: 23533
# ✅ Guardado: 29600 procesados de 53033 | Pendientes: 23433
# ✅ Guardado: 29700 procesados de 53033 | Pendientes: 23333
# ✅ Guardado: 29800 procesados de 53033 | Pendientes: 23233
# ✅ Guardado: 29900 procesados de 53033 | Pendientes: 23133
# ✅ Guardado: 30000 procesados de 53033 | Pendientes: 23033
# ✅ Guardado: 30100 procesados de 53033 | Pendientes: 22933
# ✅ Guardado: 30200 procesados de 53033 | Pendientes: 22833
# ✅ Guardado: 30300 procesados de 53033 | Pendientes: 22733
# ✅ Guardado: 30400 procesados de 53033 | Pendientes: 22633
# ✅ Guardado: 30500 procesados de 53033 | Pendientes: 22533
# ✅ Guardado: 30600 procesados de 53033 | Pendientes: 22433
# ✅ Guardado: 30700 procesados de 53033 | Pendientes: 22333
# ✅ Guardado: 30800 procesados de 53033 | Pendientes: 22233
# ✅ Guardado: 30900 procesados de 53033 | Pendientes: 22133
# ✅ Guardado: 31000 procesados de 53033 | Pendientes: 22033
# ✅ Guardado: 31100 procesados de 53033 | Pendientes: 21933
# ✅ Guardado: 31200 procesados de 53033 | Pendientes: 21833
# ✅ Guardado: 31300 procesados de 53033 | Pendientes: 21733
# ✅ Guardado: 31400 procesados de 53033 | Pendientes: 21633
# ✅ Guardado: 31500 procesados de 53033 | Pendientes: 21533
# ✅ Guardado: 31600 procesados de 53033 | Pendientes: 21433
# ✅ Guardado: 31700 procesados de 53033 | Pendientes: 21333
# ✅ Guardado: 31800 procesados de 53033 | Pendientes: 21233
# ✅ Guardado: 31900 procesados de 53033 | Pendientes: 21133
# ✅ Guardado: 32000 procesados de 53033 | Pendientes: 21033
# ✅ Guardado: 32100 procesados de 53033 | Pendientes: 20933
# ✅ Guardado: 32200 procesados de 53033 | Pendientes: 20833
# ✅ Guardado: 32300 procesados de 53033 | Pendientes: 20733
# ✅ Guardado: 32400 procesados de 53033 | Pendientes: 20633
# ✅ Guardado: 32500 procesados de 53033 | Pendientes: 20533
# ✅ Guardado: 32600 procesados de 53033 | Pendientes: 20433
# ✅ Guardado: 32700 procesados de 53033 | Pendientes: 20333
# ✅ Guardado: 32800 procesados de 53033 | Pendientes: 20233
# ✅ Guardado: 32900 procesados de 53033 | Pendientes: 20133
# ✅ Guardado: 33000 procesados de 53033 | Pendientes: 20033
# ✅ Guardado: 33100 procesados de 53033 | Pendientes: 19933
# ✅ Guardado: 33200 procesados de 53033 | Pendientes: 19833
# ✅ Guardado: 33300 procesados de 53033 | Pendientes: 19733
# ✅ Guardado: 33400 procesados de 53033 | Pendientes: 19633
# ✅ Guardado: 33500 procesados de 53033 | Pendientes: 19533
# ✅ Guardado: 33600 procesados de 53033 | Pendientes: 19433
# ✅ Guardado: 33700 procesados de 53033 | Pendientes: 19333
# ✅ Guardado: 33800 procesados de 53033 | Pendientes: 19233
# ✅ Guardado: 33900 procesados de 53033 | Pendientes: 19133
# ✅ Guardado: 34000 procesados de 53033 | Pendientes: 19033
# ✅ Guardado: 34100 procesados de 53033 | Pendientes: 18933
# ✅ Guardado: 34200 procesados de 53033 | Pendientes: 18833
# ✅ Guardado: 34300 procesados de 53033 | Pendientes: 18733
# ✅ Guardado: 34400 procesados de 53033 | Pendientes: 18633
# ✅ Guardado: 34500 procesados de 53033 | Pendientes: 18533
# ✅ Guardado: 34600 procesados de 53033 | Pendientes: 18433
# ✅ Guardado: 34700 procesados de 53033 | Pendientes: 18333
# ✅ Guardado: 34800 procesados de 53033 | Pendientes: 18233
# ✅ Guardado: 34900 procesados de 53033 | Pendientes: 18133
# ✅ Guardado: 35000 procesados de 53033 | Pendientes: 18033
# ✅ Guardado: 35100 procesados de 53033 | Pendientes: 17933
# ✅ Guardado: 35200 procesados de 53033 | Pendientes: 17833
# ✅ Guardado: 35300 procesados de 53033 | Pendientes: 17733
# ✅ Guardado: 35400 procesados de 53033 | Pendientes: 17633
# ✅ Guardado: 35500 procesados de 53033 | Pendientes: 17533
# ✅ Guardado: 35600 procesados de 53033 | Pendientes: 17433
# ✅ Guardado: 35700 procesados de 53033 | Pendientes: 17333
# ✅ Guardado: 35800 procesados de 53033 | Pendientes: 17233
# ✅ Guardado: 35900 procesados de 53033 | Pendientes: 17133
# ✅ Guardado: 36000 procesados de 53033 | Pendientes: 17033
# ✅ Guardado: 36100 procesados de 53033 | Pendientes: 16933
# ✅ Guardado: 36200 procesados de 53033 | Pendientes: 16833
# ✅ Guardado: 36300 procesados de 53033 | Pendientes: 16733
# ✅ Guardado: 36400 procesados de 53033 | Pendientes: 16633
# ✅ Guardado: 36500 procesados de 53033 | Pendientes: 16533
# ✅ Guardado: 36600 procesados de 53033 | Pendientes: 16433
# ✅ Guardado: 36700 procesados de 53033 | Pendientes: 16333
# ✅ Guardado: 36800 procesados de 53033 | Pendientes: 16233
# ✅ Guardado: 36900 procesados de 53033 | Pendientes: 16133
# ✅ Guardado: 37000 procesados de 53033 | Pendientes: 16033
# ✅ Guardado: 37100 procesados de 53033 | Pendientes: 15933
# ✅ Guardado: 37200 procesados de 53033 | Pendientes: 15833
# ✅ Guardado: 37300 procesados de 53033 | Pendientes: 15733
# ✅ Guardado: 37400 procesados de 53033 | Pendientes: 15633
# ✅ Guardado: 37500 procesados de 53033 | Pendientes: 15533
# ✅ Guardado: 37600 procesados de 53033 | Pendientes: 15433
# ✅ Guardado: 37700 procesados de 53033 | Pendientes: 15333
# ✅ Guardado: 37800 procesados de 53033 | Pendientes: 15233
# ✅ Guardado: 37900 procesados de 53033 | Pendientes: 15133
# ✅ Guardado: 38000 procesados de 53033 | Pendientes: 15033
# ✅ Guardado: 38100 procesados de 53033 | Pendientes: 14933
# ✅ Guardado: 38200 procesados de 53033 | Pendientes: 14833
# ✅ Guardado: 38300 procesados de 53033 | Pendientes: 14733
# ✅ Guardado: 38400 procesados de 53033 | Pendientes: 14633
# ✅ Guardado: 38500 procesados de 53033 | Pendientes: 14533
# ✅ Guardado: 38600 procesados de 53033 | Pendientes: 14433
# ✅ Guardado: 38700 procesados de 53033 | Pendientes: 14333
# ✅ Guardado: 38800 procesados de 53033 | Pendientes: 14233
# ✅ Guardado: 38900 procesados de 53033 | Pendientes: 14133
# ✅ Guardado: 39000 procesados de 53033 | Pendientes: 14033
# ✅ Guardado: 39100 procesados de 53033 | Pendientes: 13933
# ✅ Guardado: 39200 procesados de 53033 | Pendientes: 13833
# ✅ Guardado: 39300 procesados de 53033 | Pendientes: 13733
# ✅ Guardado: 39400 procesados de 53033 | Pendientes: 13633
# ✅ Guardado: 39500 procesados de 53033 | Pendientes: 13533
# ✅ Guardado: 39600 procesados de 53033 | Pendientes: 13433
# ✅ Guardado: 39700 procesados de 53033 | Pendientes: 13333
# ✅ Guardado: 39800 procesados de 53033 | Pendientes: 13233
# ✅ Guardado: 39900 procesados de 53033 | Pendientes: 13133
# ✅ Guardado: 40000 procesados de 53033 | Pendientes: 13033
# ✅ Guardado: 40100 procesados de 53033 | Pendientes: 12933
# ✅ Guardado: 40200 procesados de 53033 | Pendientes: 12833
# ✅ Guardado: 40300 procesados de 53033 | Pendientes: 12733
# ✅ Guardado: 40400 procesados de 53033 | Pendientes: 12633
# ✅ Guardado: 40500 procesados de 53033 | Pendientes: 12533
# ✅ Guardado: 40600 procesados de 53033 | Pendientes: 12433
# ✅ Guardado: 40700 procesados de 53033 | Pendientes: 12333
# ✅ Guardado: 40800 procesados de 53033 | Pendientes: 12233
# ✅ Guardado: 40900 procesados de 53033 | Pendientes: 12133
# ✅ Guardado: 41000 procesados de 53033 | Pendientes: 12033
# ✅ Guardado: 41100 procesados de 53033 | Pendientes: 11933
# ✅ Guardado: 41200 procesados de 53033 | Pendientes: 11833
# ✅ Guardado: 41300 procesados de 53033 | Pendientes: 11733
# ✅ Guardado: 41400 procesados de 53033 | Pendientes: 11633
# ✅ Guardado: 41500 procesados de 53033 | Pendientes: 11533
# ✅ Guardado: 41600 procesados de 53033 | Pendientes: 11433
# ✅ Guardado: 41700 procesados de 53033 | Pendientes: 11333
# ✅ Guardado: 41800 procesados de 53033 | Pendientes: 11233
# ✅ Guardado: 41900 procesados de 53033 | Pendientes: 11133
# ✅ Guardado: 42000 procesados de 53033 | Pendientes: 11033
# ✅ Guardado: 42100 procesados de 53033 | Pendientes: 10933
# ✅ Guardado: 42200 procesados de 53033 | Pendientes: 10833
# ✅ Guardado: 42300 procesados de 53033 | Pendientes: 10733
# ✅ Guardado: 42400 procesados de 53033 | Pendientes: 10633
# ✅ Guardado: 42500 procesados de 53033 | Pendientes: 10533
# ✅ Guardado: 42600 procesados de 53033 | Pendientes: 10433
# ✅ Guardado: 42700 procesados de 53033 | Pendientes: 10333
# ✅ Guardado: 42800 procesados de 53033 | Pendientes: 10233
# ✅ Guardado: 42900 procesados de 53033 | Pendientes: 10133
# ✅ Guardado: 43000 procesados de 53033 | Pendientes: 10033
# ✅ Guardado: 43100 procesados de 53033 | Pendientes: 9933
# ✅ Guardado: 43200 procesados de 53033 | Pendientes: 9833
# ✅ Guardado: 43300 procesados de 53033 | Pendientes: 9733
# ✅ Guardado: 43400 procesados de 53033 | Pendientes: 9633
# ✅ Guardado: 43500 procesados de 53033 | Pendientes: 9533
# ✅ Guardado: 43600 procesados de 53033 | Pendientes: 9433
# ✅ Guardado: 43700 procesados de 53033 | Pendientes: 9333
# ✅ Guardado: 43800 procesados de 53033 | Pendientes: 9233
# ✅ Guardado: 43900 procesados de 53033 | Pendientes: 9133
# ✅ Guardado: 44000 procesados de 53033 | Pendientes: 9033
# ✅ Guardado: 44100 procesados de 53033 | Pendientes: 8933
# ✅ Guardado: 44200 procesados de 53033 | Pendientes: 8833
# ✅ Guardado: 44300 procesados de 53033 | Pendientes: 8733
# ✅ Guardado: 44400 procesados de 53033 | Pendientes: 8633
# ✅ Guardado: 44500 procesados de 53033 | Pendientes: 8533
# ✅ Guardado: 44600 procesados de 53033 | Pendientes: 8433
# ✅ Guardado: 44700 procesados de 53033 | Pendientes: 8333
# ✅ Guardado: 44800 procesados de 53033 | Pendientes: 8233
# ✅ Guardado: 44900 procesados de 53033 | Pendientes: 8133
# ✅ Guardado: 45000 procesados de 53033 | Pendientes: 8033
# ✅ Guardado: 45100 procesados de 53033 | Pendientes: 7933
# ✅ Guardado: 45200 procesados de 53033 | Pendientes: 7833
# ✅ Guardado: 45300 procesados de 53033 | Pendientes: 7733
# ✅ Guardado: 45400 procesados de 53033 | Pendientes: 7633
# ✅ Guardado: 45500 procesados de 53033 | Pendientes: 7533
# ✅ Guardado: 45600 procesados de 53033 | Pendientes: 7433
# ✅ Guardado: 45700 procesados de 53033 | Pendientes: 7333
# ✅ Guardado: 45800 procesados de 53033 | Pendientes: 7233
# ✅ Guardado: 45900 procesados de 53033 | Pendientes: 7133
# ✅ Guardado: 46000 procesados de 53033 | Pendientes: 7033
# ✅ Guardado: 46100 procesados de 53033 | Pendientes: 6933
# ✅ Guardado: 46200 procesados de 53033 | Pendientes: 6833
# ✅ Guardado: 46300 procesados de 53033 | Pendientes: 6733
# ✅ Guardado: 46400 procesados de 53033 | Pendientes: 6633
# ✅ Guardado: 46500 procesados de 53033 | Pendientes: 6533
# ✅ Guardado: 46600 procesados de 53033 | Pendientes: 6433
# ✅ Guardado: 46700 procesados de 53033 | Pendientes: 6333
# ✅ Guardado: 46800 procesados de 53033 | Pendientes: 6233
# ✅ Guardado: 46900 procesados de 53033 | Pendientes: 6133
# ✅ Guardado: 47000 procesados de 53033 | Pendientes: 6033
# ✅ Guardado: 47100 procesados de 53033 | Pendientes: 5933
# ✅ Guardado: 47200 procesados de 53033 | Pendientes: 5833
# ✅ Guardado: 47300 procesados de 53033 | Pendientes: 5733
# ✅ Guardado: 47400 procesados de 53033 | Pendientes: 5633
# ✅ Guardado: 47500 procesados de 53033 | Pendientes: 5533
# ✅ Guardado: 47600 procesados de 53033 | Pendientes: 5433
# ✅ Guardado: 47700 procesados de 53033 | Pendientes: 5333
# ✅ Guardado: 47800 procesados de 53033 | Pendientes: 5233
# ✅ Guardado: 47900 procesados de 53033 | Pendientes: 5133
# ✅ Guardado: 48000 procesados de 53033 | Pendientes: 5033
# ✅ Guardado: 48100 procesados de 53033 | Pendientes: 4933
# ✅ Guardado: 48200 procesados de 53033 | Pendientes: 4833
# ✅ Guardado: 48300 procesados de 53033 | Pendientes: 4733
# ✅ Guardado: 48400 procesados de 53033 | Pendientes: 4633
# ✅ Guardado: 48500 procesados de 53033 | Pendientes: 4533
# ✅ Guardado: 48600 procesados de 53033 | Pendientes: 4433
# ✅ Guardado: 48700 procesados de 53033 | Pendientes: 4333
# ✅ Guardado: 48800 procesados de 53033 | Pendientes: 4233
# ✅ Guardado: 48900 procesados de 53033 | Pendientes: 4133
# ✅ Guardado: 49000 procesados de 53033 | Pendientes: 4033
# ✅ Guardado: 49100 procesados de 53033 | Pendientes: 3933
# ✅ Guardado: 49200 procesados de 53033 | Pendientes: 3833
# ✅ Guardado: 49300 procesados de 53033 | Pendientes: 3733
# ✅ Guardado: 49400 procesados de 53033 | Pendientes: 3633
# ✅ Guardado: 49500 procesados de 53033 | Pendientes: 3533
# ✅ Guardado: 49600 procesados de 53033 | Pendientes: 3433
# ✅ Guardado: 49700 procesados de 53033 | Pendientes: 3333
# ✅ Guardado: 49800 procesados de 53033 | Pendientes: 3233
# ✅ Guardado: 49900 procesados de 53033 | Pendientes: 3133
# ✅ Guardado: 50000 procesados de 53033 | Pendientes: 3033
# ✅ Guardado: 50100 procesados de 53033 | Pendientes: 2933
# ✅ Guardado: 50200 procesados de 53033 | Pendientes: 2833
# ✅ Guardado: 50300 procesados de 53033 | Pendientes: 2733
# ✅ Guardado: 50400 procesados de 53033 | Pendientes: 2633
# ✅ Guardado: 50500 procesados de 53033 | Pendientes: 2533
# ✅ Guardado: 50600 procesados de 53033 | Pendientes: 2433
# ✅ Guardado: 50700 procesados de 53033 | Pendientes: 2333
# ✅ Guardado: 50800 procesados de 53033 | Pendientes: 2233
# ✅ Guardado: 50900 procesados de 53033 | Pendientes: 2133
# ✅ Guardado: 51000 procesados de 53033 | Pendientes: 2033
# ✅ Guardado: 51100 procesados de 53033 | Pendientes: 1933
# ✅ Guardado: 51200 procesados de 53033 | Pendientes: 1833
# ✅ Guardado: 51300 procesados de 53033 | Pendientes: 1733
# ✅ Guardado: 51400 procesados de 53033 | Pendientes: 1633
# ✅ Guardado: 51500 procesados de 53033 | Pendientes: 1533
# ✅ Guardado: 51600 procesados de 53033 | Pendientes: 1433
# ✅ Guardado: 51700 procesados de 53033 | Pendientes: 1333
# ✅ Guardado: 51800 procesados de 53033 | Pendientes: 1233
# ✅ Guardado: 51900 procesados de 53033 | Pendientes: 1133
# ✅ Guardado: 52000 procesados de 53033 | Pendientes: 1033
# ✅ Guardado: 52100 procesados de 53033 | Pendientes: 933
# ✅ Guardado: 52200 procesados de 53033 | Pendientes: 833
# ✅ Guardado: 52300 procesados de 53033 | Pendientes: 733
# ✅ Guardado: 52400 procesados de 53033 | Pendientes: 633
# ✅ Guardado: 52500 procesados de 53033 | Pendientes: 533
# ✅ Guardado: 52600 procesados de 53033 | Pendientes: 433
# ✅ Guardado: 52700 procesados de 53033 | Pendientes: 333
# ✅ Guardado: 52800 procesados de 53033 | Pendientes: 233
# ✅ Guardado: 52900 procesados de 53033 | Pendientes: 133
# ✅ Guardado: 53000 procesados de 53033 | Pendientes: 33
# ✅ Guardado: 53033 procesados de 53033 | Pendientes: 0
# 🎉 Proceso finalizado y resumen guardado.
